# %% [markdown]
# <a href="https://colab.research.google.com/github/swiryat/Alice-skill/blob/master/%D0%BE%D1%82%D0%B2%D0%B5%D1%82%D1%8B_%D0%BD%D0%B0_%D0%B2%D0%BE%D0%BF%D1%80%D0%BE%D1%81%D1%8B_06_05_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df1 = pd.DataFrame({'id':[1,2,3], 'val_1':[100, 200, 330]})
df2 = pd.DataFrame({'id':[10,20,30], 'val_1':[11110, 2340, 343243]})
df3 = pd.DataFrame({'id':[100,200,300], 'val_1':[1165410, 2340, 343243]})

# %%
df1
# Out:
#    id  val_1
# 0   1    100
# 1   2    200
# 2   3    330

# %%
df2
# Out:
#    id   val_1
# 0  10   11110
# 1  20    2340
# 2  30  343243

# %%
pd.concat([df1, df2], axis=0)
# Out:
#    id   val_1
# 0   1     100
# 1   2     200
# 2   3     330
# 0  10   11110
# 1  20    2340
# 2  30  343243

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    id  val_1  id   val_1
# 0   1    100  10   11110
# 1   2    200  20    2340
# 2   3    330  30  343243

# %%
df_all = pd.concat([df1, df2, df3])
df_all
# Out:
#     id    val_1
# 0    1      100
# 1    2      200
# 2    3      330
# 0    1        a
# 1    2        b
# 2    4        c
# 0  100  1165410
# 1  200     2340
# 2  300   343243

# %%
df1 = pd.DataFrame({'id':[1,2,3], 'val_1':[100, 200, 330]})
df2 = pd.DataFrame({'id':[1,2,4], 'val_1':['a', 'b', 'c']})

# %%
df12 = df1.merge(df2, on='id', how='inner', suffixes=['_1', '_2'])
df12
# Out:
#    id  val_1_1 val_1_2
# 0   1      100       a
# 1   2      200       b

# %%
df12.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df12 = df12.set_index('id')
df12
# Out:
#     val_1_1 val_1_2
# id
# 1       100       a
# 2       200       b

# %%
df12.reset_index()
# Out:
#    id  val_1_1 val_1_2
# 0   1      100       a
# 1   2      200       b

# %%
df1 = pd.DataFrame({'id':[1,2,3], 'val_1':[100, 200, 300]}, index=[['a', 'a', 'b'], ['c', 'd', 'd']])
df1
# Out:
#      id  val_1
# a c   1    100
#   d   2    200
# b d   3    300

# %%
df_all
# Out:
#     id    val_1
# 0    1      100
# 1    2      200
# 2    3      330
# 0    1        a
# 1    2        b
# 2    4        c
# 0  100  1165410
# 1  200     2340
# 2  300   343243

# %%
df_all['id_2'] = df_all['id'].map(lambda x: 1 if x < 10 else 0)

# %%
df_all
# Out:
#     id    val_1  id_2
# 0    1      100     1
# 1    2      200     1
# 2    3      330     1
# 0    1        a     1
# 1    2        b     1
# 2    4        c     1
# 0  100  1165410     0
# 1  200     2340     0
# 2  300   343243     0

# %%
df_all_g = df_all.groupby(['id', 'id_2']).agg({'val_1':'count'}).reset_index()

# %%
# df_all.groupby(['id', 'id_2']).agg(sum_val1 = ('val_1', 'count'))

# %%
df_all_g.index
# Out:
# MultiIndex([(  1, 1),
#             (  2, 1),
#             (  3, 1),
#             (  4, 1),
#             (100, 0),
#             (200, 0),
#             (300, 0)],
#            names=['id', 'id_2'])

# %%
df_all_g = df_all.groupby(['id', 'id_2'], as_index=False).agg({'val_1':'count'})
df_all_g.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df_all_g
# Out:
#     id  id_2  val_1
# 0    1     1      2
# 1    2     1      2
# 2    3     1      1
# 3    4     1      1
# 4  100     0      1
# 5  200     0      1
# 6  300     0      1

# %%
# a + (b + c) = (a + b) + c

# %%
a.merge(b, on='').merge(c, on='')
b.merge(a, on='').merge(c, on='')

# %%
df1 = pd.DataFrame({'id':[1,2,3,4,5], 'val_1':[100, 200, 330, np.nan, np.nan]})

# %%
df1.dropna()
# Out:
#    id  val_1
# 0   1  100.0
# 1   2  200.0
# 2   3  330.0

# %%
df1
# Out:
#    id  val_1
# 0   1  100.0
# 1   2  200.0
# 2   3  330.0
# 3   4    NaN
# 4   5    NaN

# %%
df1.sort_values('val_1', ascending=True, na_position='first')
# Out:
#    id  val_1
# 0   1  100.0
# 1   2  200.0
# 2   3  330.0
# 3   4    NaN
# 4   5    NaN

# %%
import seaborn as sns
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = df[['petal_length', 'sepal_length', 'petal_width']]

# %%
sns.pairplot(df)
